# %% [markdown]
# ## Plots for zone analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Manually specified total area, area of zone1, and area of zone2 for multiple cells
areas = [
    [158061, 24183, 126887], # Cell 1: [total area, area zone 1, area zone 2]
    [168316, 15903, 148653],  # Cell 2: [total area, area zone 1, area zone 2]
    [161318, 25217, 129383],  # Cell 5: [total area, area zone 1, area zone 2]
    [130608, 24537, 99884],  # Cell 6: [total area, area zone 1, area zone 2]
    [107373, 15609, 84347],  # Cell 7: [total area, area zone 1, area zone 2]
    [119636, 16933, 97369],  # Cell 10: [total area, area zone 1, area zone 2]
    [122451, 20196, 98720],  # Cell 11: [total area, area zone 1, area zone 2]
    [116196, 21735, 90984], # Cell 17: [total area, area zone 1, area zone 2]
    [173465, 30927, 138844], # Cell 19: [total area, area zone 1, area zone 2]
    [166494, 29436, 133210], # Cell 20: [total area, area zone 1, area zone 2]
    [150254, 29516, 116846], # Cell 23: [total area, area zone 1, area zone 2]
    [152798, 22784, 126844] # Cell 24: [total area, area zone 1, area zone 2]
    # Add more cells as needed
]

# %%
# Calculate the ratio of the areas for each cell
ratios = [z1 / z2 for total, z1, z2 in areas]

# Create a boxplot of the ratios
plt.figure(figsize=(10, 6))
sns.boxplot(data=ratios)
# Plot the individual data points on top of the boxplot
sns.stripplot(data=ratios, color='red', jitter=True)

plt.title('Ratio of Zone1 to Zone2 Areas')
plt.ylabel('Ratio (area zone 1 / area zone 2)')
plt.savefig('zone_areas_ratio_boxplot.png')
plt.show()

# %%
# Calculate the percentage of the areas for each zone for each cell
percentages_zone1 = [(z1 / total) * 100 for total, z1, z2 in areas]
percentages_zone2 = [(z2 / total) * 100 for total, z1, z2 in areas]

# Combine the percentages into a single list for plotting
data = [percentages_zone1, percentages_zone2]

# Create a boxplot with two boxes: one for the percentage of zone 1 and one for the percentage of zone 2
plt.figure(figsize=(10, 6))
sns.boxplot(data=data)
plt.xticks([0, 1], ['Zone 1', 'Zone 2'])
plt.title('Percentage of Zone 1 and Zone 2 Areas')
plt.ylabel('Percentage')
plt.savefig('zone_areas_boxplot.png')
plt.show()

# %%
# Calculate the percentage of the areas for each zone for each cell
percentages_zone1 = [(z1 / total) * 100 for total, z1, z2 in areas]
percentages_zone2 = [(z2 / total) * 100 for total, z1, z2 in areas]

# Combine the percentages into a single list for plotting
data = [percentages_zone1, percentages_zone2]

# Calculate the sample size for each zone
sample_sizes = [len(percentages_zone1), len(percentages_zone2)]

# Create a boxplot with two boxes: one for the percentage of zone 1 and one for the percentage of zone 2
plt.figure(figsize=(5, 6), facecolor='black')
ax = plt.subplot(1, 1, 1, facecolor='black')
sns.boxplot(data=data, ax=ax, whiskerprops=dict(color='white'), capprops=dict(color='white'), medianprops=dict(color='white'), linewidth=2, palette=['yellow', 'cyan'])
sns.stripplot(data=data, color='red', jitter=True, size=3, ax=ax)
plt.xticks([0, 1], ['Zone 1', 'Zone 2'], color='white', fontsize=12)
plt.yticks(color='white', fontsize=12)
plt.title('Percentage of Zone 1 and Zone 2 Areas', color='white', fontsize=16)
plt.ylabel('Percentage', color='white', fontsize=14)
ax.grid(color='grey', linestyle='-', linewidth=0.5, axis='y')

# Add sample size annotations
for i, n in enumerate(sample_sizes):
    plt.text(i, plt.ylim()[0] - 0.1 * (plt.ylim()[1] - plt.ylim()[0]), f'N={n}', ha='center', color='white', fontsize=12)

plt.savefig('zone_areas_boxplot.png', facecolor='black')
plt.show()

# %%
#WHITE BACKGROUND VERSION
# Calculate the percentage of the areas for each zone for each cell
percentages_zone1 = [(z1 / total) * 100 for total, z1, z2 in areas]
percentages_zone2 = [(z2 / total) * 100 for total, z1, z2 in areas]

# Combine the percentages into a single list for plotting
data = [percentages_zone1, percentages_zone2]

# Calculate the sample size for each zone
sample_sizes = [len(percentages_zone1), len(percentages_zone2)]

sns.set_style("whitegrid")

# Create a boxplot with two boxes: one for the percentage of zone 1 and one for the percentage of zone 2
plt.figure(figsize=(8, 8), facecolor='white')
ax = plt.subplot(1, 1, 1, facecolor='white')
sns.boxplot(data=data, ax=ax, whiskerprops=dict(color='black'), capprops=dict(color='black'), medianprops=dict(color='black'), linewidth=2, palette=['yellow', 'cyan'])
# sns.boxplot(data=data, ax=ax, boxprops=dict(edgecolor='black'), whiskerprops=dict(color='black'), capprops=dict(color='black'), medianprops=dict(color='black'), linewidth=2, palette=['yellow', 'cyan'])
sns.stripplot(data=data, color='red', jitter=True, size=5, ax=ax)
plt.xticks([0, 1], ['Doublets', 'Singlets'], color='black', fontsize=18)
plt.yticks(color='black', fontsize=18)
plt.ylim(0, 100)
plt.title('Cell area %', color='black', fontsize=26, weight='bold')
plt.ylabel('%', color='black', fontsize=22)
ax.grid(color='grey', linestyle='-', linewidth=0.5, axis='y')

# Add sample size annotations
for i, n in enumerate(sample_sizes):
    plt.text(i, plt.ylim()[0] - 0.1 * (plt.ylim()[1] - plt.ylim()[0]), f'N={n}', ha='center', color='black', fontsize=14)

plt.savefig('zone_areas_boxplot.png', facecolor='white')
plt.show()

# %%
# Calculate the percentage of the areas for each zone for each cell
percentages_zone1 = [(z1 / total) * 100 for total, z1, z2 in areas]
percentages_zone2 = [(z2 / total) * 100 for total, z1, z2 in areas]
percentages_other = [100 - p1 - p2 for p1, p2 in zip(percentages_zone1, percentages_zone2)]

# Combine the percentages into a single list for plotting
data = [percentages_zone1, percentages_zone2, percentages_other]

# Create a boxplot with three boxes: Zone 1, Zone 2, Other
plt.figure(figsize=(8, 6))
sns.boxplot(data=data)
plt.xticks([0, 1, 2], ['Doublet region', 'Singlet region', 'Mouth region'])
plt.ylim(0, 100)
# plt.title('Percentage of Zone 1, Zone 2, and Other Areas')
plt.ylabel('Percentage')
plt.grid(False)
plt.savefig('zone_areas_boxplot_three.svg', format='svg', bbox_inches='tight', dpi=300)
plt.show()

# %%
import numpy as np

# Extract areas for each region
total_areas = [a[0] for a in areas]
zone1_areas = [a[1] for a in areas]
zone2_areas = [a[2] for a in areas]

# Calculate mean and standard deviation
stats = {
    'Total Area': {
        'mean': np.mean(total_areas),
        'std': np.std(total_areas, ddof=1)
    },
    'Zone 1 Area': {
        'mean': np.mean(zone1_areas),
        'std': np.std(zone1_areas, ddof=1)
    },
    'Zone 2 Area': {
        'mean': np.mean(zone2_areas),
        'std': np.std(zone2_areas, ddof=1)
    }
}

# Print results
for region, values in stats.items():
    print(f"{region}: Mean = {values['mean']:.2f}, Std = {values['std']:.2f}")
# Out:
# Total Area: Mean = 143914.17, Std = 23221.07
# Zone 1 Area: Mean = 23081.33, Std = 5279.70
# Zone 2 Area: Mean = 115997.58, Std = 20961.74

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate percentages for each zone
percentages_zone1 = [(z1 / total) * 100 for total, z1, z2 in areas]
percentages_zone2 = [(z2 / total) * 100 for total, z1, z2 in areas]
percentages_other = [100 - p1 - p2 for p1, p2 in zip(percentages_zone1, percentages_zone2)]

# Prepare data for plotting
data = [percentages_zone1, percentages_zone2, percentages_other]
sample_sizes = [len(percentages_zone1)] * 3  # All lists have the same length

sns.set_style("whitegrid")

plt.figure(figsize=(8, 8), facecolor='white')
ax = plt.subplot(1, 1, 1, facecolor='white')

# Boxplot with grayscale boxes and black lines
sns.boxplot(
    data=data,
    ax=ax,
    whiskerprops=dict(color='black'),
    capprops=dict(color='black'),
    medianprops=dict(color='black', linewidth=1.5),
    linewidth=1.5,
    palette=['0.3', '0.7', '0.9']  # grayscale: dark, medium, light
)

# Stripplot with dark grey points
sns.stripplot(
    data=data,
    color='0.2',
    jitter=True,
    size=5,
    ax=ax
)

plt.xticks([0, 1, 2], ['Zone 1', 'Zone 2', 'Other'], color='black', fontsize=16)
plt.yticks(color='black', fontsize=16)
plt.ylim(0, 100)
# plt.title('Percentage of Zone 1, Zone 2, and Other Areas', color='black', fontsize=20, weight='bold')
plt.ylabel('Percentage', color='black', fontsize=18)

# Add tick marks to both axes
ax.tick_params(axis='both', which='both', direction='out', length=6, width=1.5, colors='black')

# Set the outline (spines) of the plot to black
for spine in ax.spines.values():
    spine.set_edgecolor('black')
    spine.set_linewidth(2)

ax.grid(False)

plt.savefig('zone_areas_boxplot_three.png', dpi=300, facecolor='white', bbox_inches='tight')
plt.savefig('zone_areas_boxplot_three.svg', format='svg', facecolor='white', bbox_inches='tight')
plt.show()

# %%
import numpy as np

# Assuming percentages_zone1, percentages_zone2, percentages_other are already defined
stats_percentages = {
    'Zone 1 Percentage': {
        'mean': np.mean(percentages_zone1),
        'std': np.std(percentages_zone1, ddof=1)
    },
    'Zone 2 Percentage': {
        'mean': np.mean(percentages_zone2),
        'std': np.std(percentages_zone2, ddof=1)
    },
    'Other Percentage': {
        'mean': np.mean(percentages_other),
        'std': np.std(percentages_other, ddof=1)
    }
}

for region, values in stats_percentages.items():
    print(f"{region}: Mean = {values['mean']:.2f}%, Std = {values['std']:.2f}%")
# Out:
# Zone 1 Percentage: Mean = 16.09%, Std = 2.78%
# Zone 2 Percentage: Mean = 80.41%, Std = 3.03%
# Other Percentage: Mean = 3.49%, Std = 1.47%

# %%
# WHITE BACKGROUND VERSION
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate the percentage of the areas for each zone for each cell
percentages_zone1 = [(z1 / total) * 100 for total, z1, z2 in areas]
percentages_zone2 = [(z2 / total) * 100 for total, z1, z2 in areas]

# Combine the percentages into a single list for plotting
data = [percentages_zone1, percentages_zone2]

# Calculate the sample size for each zone
sample_sizes = [len(percentages_zone1), len(percentages_zone2)]

sns.set_style("whitegrid")

# Create a boxplot with two boxes: one for the percentage of zone 1 and one for the percentage of zone 2
plt.figure(figsize=(5, 6), facecolor='white')
ax = plt.subplot(1, 1, 1, facecolor='white')

# Boxplot with grayscale boxes and black edges
sns.boxplot(
    data=data,
    ax=ax,
    whiskerprops=dict(color='black'),
    capprops=dict(color='black'),
    medianprops=dict(color='black', linewidth=1.5),
    linewidth=1.5,
    palette=['0.3', '0.7']  # grayscale: dark grey, light grey
)

# Stripplot with dark grey points
sns.stripplot(
    data=data,
    color='0.2',
    jitter=True,
    size=3,
    ax=ax
)

# Axis labels, ticks, and title in black
plt.xticks([0, 1], ['Zone 1', 'Zone 2'], color='black', fontsize=14)
plt.yticks(color='black', fontsize=14)
plt.title('Percentage of Zone 1 and Zone 2 Areas', color='black', fontsize=16, weight='bold')
plt.ylabel('Percentage', color='black', fontsize=14)

# Grid lines in light grey
ax.grid(color='black', linestyle='-', linewidth=0.5, alpha=0.3, axis='y')

# Add sample size annotations (in black below x-axis)
for i, n in enumerate(sample_sizes):
    plt.text(
        i,
        plt.ylim()[0] - 0.05 * (plt.ylim()[1] - plt.ylim()[0]),
        f'N={n}',
        ha='center',
        color='black',
        fontsize=12
    )

# Save in both PNG and SVG with white background
plt.savefig('zone_areas_boxplot.png', dpi=300, facecolor='white', bbox_inches='tight')
plt.savefig('zone_areas_boxplot.svg', format='svg', facecolor='white', bbox_inches='tight')

plt.show()

# %%
# Create a violin plot of the percentage of zone 1 and zone 2 areas and save figure
plt.figure(figsize=(10, 6))
sns.violinplot(data=data)
plt.xticks([0, 1], ['Zone 1', 'Zone 2'])
plt.title('Percentage of Zone 1 and Zone 2 Areas')
plt.ylabel('Percentage')
plt.savefig('zone_areas_violinplot.png')
plt.show()

# %%
# Print the sum of the percentages for each cell
# It should not be 100% because there is also the OA which is not included in the zones
for i, (p1, p2) in enumerate(zip(percentages_zone1, percentages_zone2), 1):
    print(f'Cell {i}: Zone 1: {p1:.2f}%, Zone 2: {p2:.2f}%, Total: {p1 + p2:.2f}%')
# Out:
# Cell 1: Zone 1: 15.30%, Zone 2: 80.28%, Total: 95.58%
# Cell 2: Zone 1: 9.45%, Zone 2: 88.32%, Total: 97.77%
# Cell 3: Zone 1: 15.63%, Zone 2: 80.20%, Total: 95.84%
# Cell 4: Zone 1: 18.79%, Zone 2: 76.48%, Total: 95.26%
# Cell 5: Zone 1: 14.54%, Zone 2: 78.56%, Total: 93.09%
# Cell 6: Zone 1: 14.15%, Zone 2: 81.39%, Total: 95.54%
# Cell 7: Zone 1: 16.49%, Zone 2: 80.62%, Total: 97.11%
# Cell 8: Zone 1: 18.71%, Zone 2: 78.30%, Total: 97.01%
# Cell 9: Zone 1: 17.83%, Zone 2: 80.04%, Total: 97.87%
# Cell 10: Zone 1: 17.68%, Zone 2: 80.01%, Total: 97.69%

# %% [markdown]
# ## Plots for cell shape analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# # import excel file with cell shape data as a pandas dataframe
# df = pd.read_excel("W:/Users/Daphne/WT_data/shape_analysis_IF_WT.xlsx")
#
# # Display the first few rows of the dataframe
# df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 # import excel file with cell shape data as a pandas dataframe
# ----> 2 df = pd.read_excel("W:/Users/Daphne/WT_data/shape_analysis_IF_WT.xlsx")
#       4 # Display the first few rows of the dataframe
#       5 df.head()
#
# File ~\AppData\Local\mambaforge\lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
# ...

# %%
# # Extract relevant columns for cell length, cell width, and aspect ratio
# cell_length = df['Length (micron)']
# cell_width = df['Width (micron)']
# aspect_ratio = df['Aspect Ratio (length/width)']
#
# # Create a figure with subplots for each measurement
# plt.figure(figsize=(15, 5))
#
# # Boxplot for cell length
# plt.subplot(1, 3, 1)
# sns.boxplot(data=cell_length)
# sns.stripplot(data=cell_length, color='red', jitter=True)
# plt.title('Cell Length')
# plt.ylabel('Length')
#
# # Boxplot for cell width
# plt.subplot(1, 3, 2)
# sns.boxplot(data=cell_width)
# sns.stripplot(data=cell_width, color='red', jitter=True)
# plt.title('Cell Width')
# plt.ylabel('Width')
#
# # Boxplot for aspect ratio
# plt.subplot(1, 3, 3)
# sns.boxplot(data=aspect_ratio)
# sns.stripplot(data=aspect_ratio, color='red', jitter=True)
# plt.title('Aspect Ratio')
# plt.ylabel('Aspect Ratio')
#
# # Show the plots
# plt.tight_layout()
# plt.savefig('cell_shape_boxplot.png')
# plt.show()

# %%
# # Create a violin plot for each measurement
# plt.figure(figsize=(15, 5))
#
# # Violin plot for cell length
# plt.subplot(1, 3, 1)
# sns.violinplot(data=cell_length)
# plt.title('Cell Length')
# plt.ylabel('Length')
#
# # Violin plot for cell width
# plt.subplot(1, 3, 2)
# sns.violinplot(data=cell_width)
# plt.title('Cell Width')
# plt.ylabel('Width')
#
# # Violin plot for aspect ratio
# plt.subplot(1, 3, 3)
# sns.violinplot(data=aspect_ratio)
# plt.title('Aspect Ratio')
# plt.ylabel('Aspect Ratio')
#
# # Show the plots
# plt.tight_layout()
# plt.savefig('cell_shape_violinplot.png')
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 6
#       4 # Violin plot for cell length
#       5 plt.subplot(1, 3, 1)
# ----> 6 sns.violinplot(data=cell_length)
#       7 plt.title('Cell Length')
#       8 plt.ylabel('Length')
#
# NameError: name 'cell_length' is not defined

# %% [markdown]
# ## Plots for cell shape analysis for different cell types

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Open the excel files with cell shape data for each RNAi type
df_wt = pd.read_excel("W:/Users/Daphne/DATA FOR APS/WT_data/shape_analysis_IF_WT.xlsx")
df_control = pd.read_excel("W:/Users/Daphne/DATA FOR APS/control_data/shape_analysis_IF_control.xlsx")
df_SF7a = pd.read_excel("W:/Users/Daphne/DATA FOR APS/SF7a_data/shape_analysis_IF_SF7a.xlsx")
df_ICL10 = pd.read_excel("W:/Users/Daphne/DATA FOR APS/ICL10_data/shape_analysis_IF_ICL10.xlsx")
df_ICL11 = pd.read_excel("W:/Users/Daphne/DATA FOR APS/ICL11_data/shape_analysis_IF_ICL11.xlsx")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Open the excel files with cell shape data for each RNAi type
# ----> 2 df_wt = pd.read_excel("W:/Users/Daphne/DATA FOR APS/WT_data/shape_analysis_IF_WT.xlsx")
#       3 df_control = pd.read_excel("W:/Users/Daphne/DATA FOR APS/control_data/shape_analysis_IF_control.xlsx")
#       4 df_SF7a = pd.read_excel("W:/Users/Daphne/DATA FOR APS/SF7a_data/shape_analysis_IF_SF7a.xlsx")
#
# NameError: name 'pd' is not defined

# %%
# Extract relevant columns for cell length (= Major), cell width (= Minor), and aspect ratio (= AR) for each RNAi type
cell_length_wt = df_wt['Major']
cell_width_wt = df_wt['Minor']
aspect_ratio_wt = df_wt['AR']

cell_length_control = df_control['Major']
cell_width_control = df_control['Minor']
aspect_ratio_control = df_control['AR']

cell_length_SF7a = df_SF7a['Major']
cell_width_SF7a = df_SF7a['Minor']
aspect_ratio_SF7a = df_SF7a['AR']

cell_length_ICL10 = df_ICL10['Major']
cell_width_ICL10 = df_ICL10['Minor']
aspect_ratio_ICL10 = df_ICL10['AR']

cell_length_ICL11 = df_ICL11['Major']
cell_width_ICL11 = df_ICL11['Minor']
aspect_ratio_ICL11 = df_ICL11['AR']

# %%
# Create a figure with subplots for each measurement
plt.figure(figsize=(15, 5))

# Boxplot for cell length
plt.subplot(1, 3, 1)
sns.boxplot(data=[cell_length_wt.tolist(), cell_length_control.tolist(), cell_length_SF7a.tolist(), cell_length_ICL10.tolist(), cell_length_ICL11.tolist()])
plt.xticks([0, 1, 2, 3, 4], ['WT', 'Control', 'SF7a', 'ICL10', 'ICL11'])
plt.title('Cell Length')
plt.ylabel('Length (micron)')

# Boxplot for cell width
plt.subplot(1, 3, 2)
sns.boxplot(data=[cell_width_wt.tolist(), cell_width_control.tolist(), cell_width_SF7a.tolist(), cell_width_ICL10.tolist(), cell_width_ICL11.tolist()])
plt.xticks([0, 1, 2, 3, 4], ['WT', 'Control', 'SF7a', 'ICL10', 'ICL11'])
plt.title('Cell Width')
plt.ylabel('Width (micron)')

# Boxplot for aspect ratio
plt.subplot(1, 3, 3)
sns.boxplot(data=[aspect_ratio_wt.tolist(), aspect_ratio_control.tolist(), aspect_ratio_SF7a.tolist(), aspect_ratio_ICL10.tolist(), aspect_ratio_ICL11.tolist()])
plt.xticks([0, 1, 2, 3, 4], ['WT', 'Control', 'SF7a', 'ICL10', 'ICL11'])
plt.title('Aspect Ratio')
plt.ylabel('Aspect Ratio')

# Show the plots
plt.tight_layout()
plt.savefig('cell_shape_boxplot_RNAi.png')
plt.show()

# %%
# Calculate the sample size for each condition
sample_sizes = [
    len(cell_length_wt), len(cell_length_control), len(cell_length_SF7a), len(cell_length_ICL10), len(cell_length_ICL11)
]

# Create a figure with subplots for each measurement
plt.figure(figsize=(15, 5))

# Boxplot for cell length
plt.subplot(1, 3, 1)
sns.boxplot(data=[cell_length_wt.tolist(), cell_length_control.tolist(), cell_length_SF7a.tolist(), cell_length_ICL10.tolist(), cell_length_ICL11.tolist()])
sns.stripplot(data=[cell_length_wt.tolist(), cell_length_control.tolist(), cell_length_SF7a.tolist(), cell_length_ICL10.tolist(), cell_length_ICL11.tolist()], color='red', jitter=True)
plt.xticks([0, 1, 2, 3, 4], ['WT', 'Control', 'SF7a', 'ICL10', 'ICL11'])
plt.title('Cell Length')
plt.ylabel('Length (micron)')
for i, n in enumerate(sample_sizes):
    plt.text(i, plt.ylim()[0] - 0.1 * (plt.ylim()[1] - plt.ylim()[0]), f'N={n}', ha='center')

# Boxplot for cell width
plt.subplot(1, 3, 2)
sns.boxplot(data=[cell_width_wt.tolist(), cell_width_control.tolist(), cell_width_SF7a.tolist(), cell_width_ICL10.tolist(), cell_width_ICL11.tolist()])
sns.stripplot(data=[cell_width_wt.tolist(), cell_width_control.tolist(), cell_width_SF7a.tolist(), cell_width_ICL10.tolist(), cell_width_ICL11.tolist()], color='red', jitter=True)
plt.xticks([0, 1, 2, 3, 4], ['WT', 'Control', 'SF7a', 'ICL10', 'ICL11'])
plt.title('Cell Width')
plt.ylabel('Width (micron)')
for i, n in enumerate(sample_sizes):
    plt.text(i, plt.ylim()[0] - 0.1 * (plt.ylim()[1] - plt.ylim()[0]), f'N={n}', ha='center')

# Boxplot for aspect ratio
plt.subplot(1, 3, 3)
sns.boxplot(data=[aspect_ratio_wt.tolist(), aspect_ratio_control.tolist(), aspect_ratio_SF7a.tolist(), aspect_ratio_ICL10.tolist(), aspect_ratio_ICL11.tolist()])
sns.stripplot(data=[aspect_ratio_wt.tolist(), aspect_ratio_control.tolist(), aspect_ratio_SF7a.tolist(), aspect_ratio_ICL10.tolist(), aspect_ratio_ICL11.tolist()], color='red', jitter=True)
plt.xticks([0, 1, 2, 3, 4], ['WT', 'Control', 'SF7a', 'ICL10', 'ICL11'])
plt.title('Aspect Ratio')
plt.ylabel('Aspect Ratio')
for i, n in enumerate(sample_sizes):
    plt.text(i, plt.ylim()[0] - 0.1 * (plt.ylim()[1] - plt.ylim()[0]), f'N={n}', ha='center')

# Show the plots
plt.tight_layout()
plt.savefig('cell_shape_boxplot_RNAi.png')
plt.show()

# %%
# plot the same for the area of the cells
# Extract relevant columns for cell area for each RNAi type
cell_area_wt = df_wt['Area']
cell_area_control = df_control['Area']
cell_area_SF7a = df_SF7a['Area']
cell_area_ICL10 = df_ICL10['Area']
cell_area_ICL11 = df_ICL11['Area']

# Calculate the sample size for each condition
sample_sizes_area = [
    len(cell_area_wt), len(cell_area_control), len(cell_area_SF7a), len(cell_area_ICL10), len(cell_area_ICL11)
]

# Create a figure with subplots for each measurement
plt.figure(figsize=(15, 5))

# Boxplot for cell area
plt.subplot(1, 1, 1)
sns.boxplot(data=[cell_area_wt.tolist(), cell_area_control.tolist(), cell_area_SF7a.tolist(), cell_area_ICL10.tolist(), cell_area_ICL11.tolist()])
sns.stripplot(data=[cell_area_wt.tolist(), cell_area_control.tolist(), cell_area_SF7a.tolist(), cell_area_ICL10.tolist(), cell_area_ICL11.tolist()], color='red', jitter=True)
plt.xticks([0, 1, 2, 3, 4], ['WT', 'Control', 'SF7a', 'ICL10', 'ICL11'])
plt.title('Cell Area')
plt.ylabel('Area (micron^2)')
for i, n in enumerate(sample_sizes_area):
    plt.text(i, plt.ylim()[0] - 0.1 * (plt.ylim()[1] - plt.ylim()[0]), f'N={n}', ha='center')

# Show the plots
plt.tight_layout()
plt.savefig('cell_area_boxplot_RNAi.png')
plt.show()

# %%
# Create a violin plot for each measurement
plt.figure(figsize=(15, 5))

# Violin plot for cell length
plt.subplot(1, 3, 1)
sns.violinplot(data=[cell_length_wt.tolist(), cell_length_control.tolist(), cell_length_SF7a.tolist(), cell_length_ICL10.tolist(), cell_length_ICL11.tolist()])
plt.xticks([0, 1, 2, 3, 4], ['WT', 'Control', 'SF7a', 'ICL10', 'ICL11'])
plt.title('Cell Length')

# Violin plot for cell width
plt.subplot(1, 3, 2)
sns.violinplot(data=[cell_width_wt.tolist(), cell_width_control.tolist(), cell_width_SF7a.tolist(), cell_width_ICL10.tolist(), cell_width_ICL11.tolist()])
plt.xticks([0, 1, 2, 3, 4], ['WT', 'Control', 'SF7a', 'ICL10', 'ICL11'])
plt.title('Cell Width')

# Violin plot for aspect ratio
plt.subplot(1, 3, 3)
sns.violinplot(data=[aspect_ratio_wt.tolist(), aspect_ratio_control.tolist(), aspect_ratio_SF7a.tolist(), aspect_ratio_ICL10.tolist(), aspect_ratio_ICL11.tolist()])
plt.xticks([0, 1, 2, 3, 4], ['WT', 'Control', 'SF7a', 'ICL10', 'ICL11'])
plt.title('Aspect Ratio')

# Show the plots
plt.tight_layout()
plt.savefig('cell_shape_violinplot_RNAi.png')
plt.show()

# %%
# now put all the boxplots in one figure with area, length, width and aspect ratio
# Create a figure with subplots for each measurement
plt.figure(figsize=(20, 5))

# Boxplot for cell area
plt.subplot(1, 4, 1)
sns.boxplot(data=[cell_area_wt.tolist(), cell_area_control.tolist(), cell_area_SF7a.tolist(), cell_area_ICL10.tolist(), cell_area_ICL11.tolist()])
sns.stripplot(data=[cell_area_wt.tolist(), cell_area_control.tolist(), cell_area_SF7a.tolist(), cell_area_ICL10.tolist(), cell_area_ICL11.tolist()], color='red', jitter=True)
plt.xticks([0, 1, 2, 3, 4], ['WT', 'Control', 'SF7a', 'ICL10', 'ICL11'])
plt.title('Cell Area')
plt.ylabel('Area (micron^2)')
for i, n in enumerate(sample_sizes_area):
    plt.text(i, plt.ylim()[0] - 0.1 * (plt.ylim()[1] - plt.ylim()[0]), f'N={n}', ha='center')

# Boxplot for cell length
plt.subplot(1, 4, 2)
sns.boxplot(data=[cell_length_wt.tolist(), cell_length_control.tolist(), cell_length_SF7a.tolist(), cell_length_ICL10.tolist(), cell_length_ICL11.tolist()])
sns.stripplot(data=[cell_length_wt.tolist(), cell_length_control.tolist(), cell_length_SF7a.tolist(), cell_length_ICL10.tolist(), cell_length_ICL11.tolist()], color='red', jitter=True)
plt.xticks([0, 1, 2, 3, 4], ['WT', 'Control', 'SF7a', 'ICL10', 'ICL11'])
plt.title('Cell Length')
plt.ylabel('Length (micron)')
for i, n in enumerate(sample_sizes):
    plt.text(i, plt.ylim()[0] - 0.1 * (plt.ylim()[1] - plt.ylim()[0]), f'N={n}', ha='center')

# Boxplot for cell width
plt.subplot(1, 4, 3)
sns.boxplot(data=[cell_width_wt.tolist(), cell_width_control.tolist(), cell_width_SF7a.tolist(), cell_width_ICL10.tolist(), cell_width_ICL11.tolist()])
sns.stripplot(data=[cell_width_wt.tolist(), cell_width_control.tolist(), cell_width_SF7a.tolist(), cell_width_ICL10.tolist(), cell_width_ICL11.tolist()], color='red', jitter=True)
plt.xticks([0, 1, 2, 3, 4], ['WT', 'Control', 'SF7a', 'ICL10', 'ICL11'])
plt.title('Cell Width')
plt.ylabel('Width (micron)')
for i, n in enumerate(sample_sizes):
    plt.text(i, plt.ylim()[0] - 0.1 * (plt.ylim()[1] - plt.ylim()[0]), f'N={n}', ha='center')

# Boxplot for aspect ratio
plt.subplot(1, 4, 4)
sns.boxplot(data=[aspect_ratio_wt.tolist(), aspect_ratio_control.tolist(), aspect_ratio_SF7a.tolist(), aspect_ratio_ICL10.tolist(), aspect_ratio_ICL11.tolist()])
sns.stripplot(data=[aspect_ratio_wt.tolist(), aspect_ratio_control.tolist(), aspect_ratio_SF7a.tolist(), aspect_ratio_ICL10.tolist(), aspect_ratio_ICL11.tolist()], color='red', jitter=True)
plt.xticks([0, 1, 2, 3, 4], ['WT', 'Control', 'SF7a', 'ICL10', 'ICL11'])
plt.title('Aspect Ratio')
plt.ylabel('Aspect Ratio')
for i, n in enumerate(sample_sizes):
    plt.text(i, plt.ylim()[0] - 0.1 * (plt.ylim()[1] - plt.ylim()[0]), f'N={n}', ha='center')

# Show the plots
plt.tight_layout()
plt.savefig('cell_shape_boxplot_RNAi_all.png')
plt.show()

# %%
# SAME PLOTS BUT SAVE WITH BLACK BACKGROUND
# Create a figure with subplots for each measurement
plt.figure(figsize=(20, 5), facecolor='black')

# Boxplot for cell area
ax1 = plt.subplot(1, 4, 1, facecolor='black')
sns.boxplot(data=[cell_area_wt.tolist(), cell_area_control.tolist(), cell_area_SF7a.tolist(), cell_area_ICL10.tolist(), cell_area_ICL11.tolist()], ax=ax1, whiskerprops=dict(color='white'), capprops=dict(color='white'), medianprops=dict(color='white'))
sns.stripplot(data=[cell_area_wt.tolist(), cell_area_control.tolist(), cell_area_SF7a.tolist(), cell_area_ICL10.tolist(), cell_area_ICL11.tolist()], color='red', jitter=True, size=3, ax=ax1)
plt.xticks([0, 1, 2, 3, 4], ['WT', 'Control', 'SF7a', 'ICL10', 'ICL11'], color='white')
plt.yticks(color='white')
plt.title('Cell Area', color='white')
plt.ylabel('Area (micron^2)', color='white')
ax1.grid(color='grey', linestyle='-', linewidth=0.5, axis='y')
for i, n in enumerate(sample_sizes_area):
    plt.text(i, plt.ylim()[0] - 0.1 * (plt.ylim()[1] - plt.ylim()[0]), f'N={n}', ha='center', color='white')

# Boxplot for cell length
ax2 = plt.subplot(1, 4, 2, facecolor='black')
sns.boxplot(data=[cell_length_wt.tolist(), cell_length_control.tolist(), cell_length_SF7a.tolist(), cell_length_ICL10.tolist(), cell_length_ICL11.tolist()], ax=ax2, whiskerprops=dict(color='white'), capprops=dict(color='white'), medianprops=dict(color='white'))
sns.stripplot(data=[cell_length_wt.tolist(), cell_length_control.tolist(), cell_length_SF7a.tolist(), cell_length_ICL10.tolist(), cell_length_ICL11.tolist()], color='red', jitter=True, size=3, ax=ax2)
plt.xticks([0, 1, 2, 3, 4], ['WT', 'Control', 'SF7a', 'ICL10', 'ICL11'], color='white')
plt.yticks(color='white')
plt.title('Cell Length', color='white')
plt.ylabel('Length (micron)', color='white')
ax2.grid(color='grey', linestyle='-', linewidth=0.5, axis='y')
for i, n in enumerate(sample_sizes):
    plt.text(i, plt.ylim()[0] - 0.1 * (plt.ylim()[1] - plt.ylim()[0]), f'N={n}', ha='center', color='white')

# Boxplot for cell width
ax3 = plt.subplot(1, 4, 3, facecolor='black')
sns.boxplot(data=[cell_width_wt.tolist(), cell_width_control.tolist(), cell_width_SF7a.tolist(), cell_width_ICL10.tolist(), cell_width_ICL11.tolist()], ax=ax3, whiskerprops=dict(color='white'), capprops=dict(color='white'), medianprops=dict(color='white'))
sns.stripplot(data=[cell_width_wt.tolist(), cell_width_control.tolist(), cell_width_SF7a.tolist(), cell_width_ICL10.tolist(), cell_width_ICL11.tolist()], color='red', jitter=True, size=3, ax=ax3)
plt.xticks([0, 1, 2, 3, 4], ['WT', 'Control', 'SF7a', 'ICL10', 'ICL11'], color='white')
plt.yticks(color='white')
plt.title('Cell Width', color='white')
plt.ylabel('Width (micron)', color='white')
ax3.grid(color='grey', linestyle='-', linewidth=0.5, axis='y')
for i, n in enumerate(sample_sizes):
    plt.text(i, plt.ylim()[0] - 0.1 * (plt.ylim()[1] - plt.ylim()[0]), f'N={n}', ha='center', color='white')

# Boxplot for aspect ratio
ax4 = plt.subplot(1, 4, 4, facecolor='black')
sns.boxplot(data=[aspect_ratio_wt.tolist(), aspect_ratio_control.tolist(), aspect_ratio_SF7a.tolist(), aspect_ratio_ICL10.tolist(), aspect_ratio_ICL11.tolist()], ax=ax4, whiskerprops=dict(color='white'), capprops=dict(color='white'), medianprops=dict(color='white'))
sns.stripplot(data=[aspect_ratio_wt.tolist(), aspect_ratio_control.tolist(), aspect_ratio_SF7a.tolist(), aspect_ratio_ICL10.tolist(), aspect_ratio_ICL11.tolist()], color='red', jitter=True, size=3, ax=ax4)
plt.xticks([0, 1, 2, 3, 4], ['WT', 'Control', 'SF7a', 'ICL10', 'ICL11'], color='white')
plt.yticks(color='white')
plt.title('Aspect Ratio', color='white')
plt.ylabel('Aspect Ratio', color='white')
ax4.grid(color='grey', linestyle='-', linewidth=0.5, axis='y')
for i, n in enumerate(sample_sizes):
    plt.text(i, plt.ylim()[0] - 0.1 * (plt.ylim()[1] - plt.ylim()[0]), f'N={n}', ha='center', color='white')

# Show the plots
plt.tight_layout()
plt.savefig('cell_shape_boxplot_RNAi_all.png', facecolor='black')
plt.show()

# %%
# PLOTs FOR APS MEETING
# Calculate the sample size for each condition
sample_sizes = [
    len(cell_length_control), len(cell_length_SF7a), len(cell_length_ICL10)
]

# Create a figure with subplots for each measurement
plt.figure(figsize=(10, 6), facecolor='black')

# Boxplot for cell area
ax1 = plt.subplot(1, 2, 1, facecolor='black')
sns.boxplot(data=[cell_area_control.tolist(), cell_area_SF7a.tolist(), cell_area_ICL10.tolist()], ax=ax1, whiskerprops=dict(color='white'), capprops=dict(color='white'), medianprops=dict(color='white'), linewidth=2, palette=['grey', 'orange', 'cyan'])
sns.stripplot(data=[cell_area_control.tolist(), cell_area_SF7a.tolist(), cell_area_ICL10.tolist()], color='red', jitter=True, size=6, ax=ax1)
plt.xticks([0, 1, 2], ['Control', 'SF', 'Centrin'], color='white', fontsize=20)
plt.yticks(color='white', fontsize=20)
plt.title('Cell Area', color='white', fontsize=24)
plt.ylabel('Area (µm²)', color='white', fontsize=22)
ax1.grid(color='grey', linestyle='-', linewidth=0.5, axis='y')
for i, n in enumerate(sample_sizes):
    plt.text(i, plt.ylim()[0] - 0.1 * (plt.ylim()[1] - plt.ylim()[0]), f'N={n}', ha='center', color='white', fontsize=12)

# Boxplot for aspect ratio
ax4 = plt.subplot(1, 2, 2, facecolor='black')
sns.boxplot(data=[aspect_ratio_control.tolist(), aspect_ratio_SF7a.tolist(), aspect_ratio_ICL10.tolist()], ax=ax4, whiskerprops=dict(color='white'), capprops=dict(color='white'), medianprops=dict(color='white'), linewidth=2, palette=['grey', 'orange', 'cyan'])
sns.stripplot(data=[aspect_ratio_control.tolist(), aspect_ratio_SF7a.tolist(), aspect_ratio_ICL10.tolist()], color='red', jitter=True, size=6, ax=ax4)
plt.xticks([0, 1, 2], ['Control', 'SF', 'Centrin'], color='white', fontsize=20)
plt.yticks(color='white', fontsize=20)
plt.title('Aspect Ratio', color='white', fontsize=24)
plt.ylabel('Aspect Ratio', color='white', fontsize=22)
ax4.grid(color='grey', linestyle='-', linewidth=0.5, axis='y')
for i, n in enumerate(sample_sizes):
    plt.text(i, plt.ylim()[0] - 0.1 * (plt.ylim()[1] - plt.ylim()[0]), f'N={n}', ha='center', color='white', fontsize=12)

# Adjust the space between subplots
plt.subplots_adjust(wspace=0.4)

# Show the plots
# plt.tight_layout()
plt.savefig('cell_shape_boxplot_RNAi_all.png', facecolor='black')
plt.show()
