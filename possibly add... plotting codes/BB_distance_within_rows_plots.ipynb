# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# # Set the seaborn theme to dark mode
# sns.set_theme(style="darkgrid")

# %% [markdown]
# ## WT cells

# %%
# Load the CSV files for each cell and zone
cell5_zone1 = pd.read_csv('W:/Users/Daphne/WT_RESULTS/WT_ExM_Centrin_2024/BB measurements cell 5/Zone 1/exclude doublets/single_gaussian_fit_parameters.csv')
cell5_zone1_includedoublets = pd.read_csv('W:/Users/Daphne/WT_RESULTS/WT_ExM_Centrin_2024/BB measurements cell 5/Zone 1/include doublets/gmm_fit_parameters.csv')
cell5_zone2 = pd.read_csv('W:/Users/Daphne/WT_RESULTS/WT_ExM_Centrin_2024/BB measurements cell 5/Zone 2/exclude doublets/single_gaussian_fit_parameters.csv')
cell5_zone2_includedoublets = pd.read_csv('W:/Users/Daphne/WT_RESULTS/WT_ExM_Centrin_2024/BB measurements cell 5/Zone 2/include doublets/gmm_fit_parameters.csv')

cell6_zone1 = pd.read_csv('W:/Users/Daphne/WT_RESULTS/WT_ExM_Centrin_2024/BB measurements cell 6/Zone 1/exclude doublets/single_gaussian_fit_parameters.csv')
cell6_zone1_includedoublets = pd.read_csv('W:/Users/Daphne/WT_RESULTS/WT_ExM_Centrin_2024/BB measurements cell 6/Zone 1/include doublets/gmm_fit_parameters.csv')
cell6_zone2 = pd.read_csv('W:/Users/Daphne/WT_RESULTS/WT_ExM_Centrin_2024/BB measurements cell 6/Zone 2/exclude doublets/single_gaussian_fit_parameters.csv')
cell6_zone2_includedoublets = pd.read_csv('W:/Users/Daphne/WT_RESULTS/WT_ExM_Centrin_2024/BB measurements cell 6/Zone 2/include doublets/gmm_fit_parameters.csv')

cell7_zone1 = pd.read_csv('W:/Users/Daphne/WT_RESULTS/WT_ExM_Centrin_2024/BB measurements cell 7/Zone 1/exclude doublets/single_gaussian_fit_parameters.csv')
cell7_zone1_includedoublets = pd.read_csv('W:/Users/Daphne/WT_RESULTS/WT_ExM_Centrin_2024/BB measurements cell 7/Zone 1/include doublets/gmm_fit_parameters.csv')
cell7_zone2 = pd.read_csv('W:/Users/Daphne/WT_RESULTS/WT_ExM_Centrin_2024/BB measurements cell 7/Zone 2/exclude doublets/single_gaussian_fit_parameters.csv')
cell7_zone2_includedoublets = pd.read_csv('W:/Users/Daphne/WT_RESULTS/WT_ExM_Centrin_2024/BB measurements cell 7/Zone 2/include doublets/gmm_fit_parameters.csv')

cell10_zone1 = pd.read_csv('W:/Users/Daphne/WT_RESULTS/WT_ExM_Centrin_2024/BB measurements cell 10/Zone 1/exclude doublets/single_gaussian_fit_parameters.csv')
cell10_zone1_includedoublets = pd.read_csv('W:/Users/Daphne/WT_RESULTS/WT_ExM_Centrin_2024/BB measurements cell 10/Zone 1/include doublets/gmm_fit_parameters.csv')
cell10_zone2 = pd.read_csv('W:/Users/Daphne/WT_RESULTS/WT_ExM_Centrin_2024/BB measurements cell 10/Zone 2/exclude doublets/single_gaussian_fit_parameters.csv')
cell10_zone2_includedoublets = pd.read_csv('W:/Users/Daphne/WT_RESULTS/WT_ExM_Centrin_2024/BB measurements cell 10/Zone 2/include doublets/gmm_fit_parameters.csv')

# same for cells 11, 17, 19, 20, 23, and 24. Not the includedoublets files. path to the files: 'W:/Users/Daphne/WT_RESULTS/WT_ExM_Centrin/Zone analysis/BB measurements cell X/Zone Y/single_gaussian_fit_parameters.csv'
cell11_zone1 = pd.read_csv('W:/Users/Daphne/WT_RESULTS/WT_ExM_Centrin/Zone analysis/BB measurements cell 11/Zone 1/single_gaussian_fit_parameters.csv')
cell11_zone2 = pd.read_csv('W:/Users/Daphne/WT_RESULTS/WT_ExM_Centrin/Zone analysis/BB measurements cell 11/Zone 2/single_gaussian_fit_parameters.csv')
cell17_zone1 = pd.read_csv('W:/Users/Daphne/WT_RESULTS/WT_ExM_Centrin/Zone analysis/BB measurements cell 17/Zone 1/single_gaussian_fit_parameters.csv')
cell17_zone2 = pd.read_csv('W:/Users/Daphne/WT_RESULTS/WT_ExM_Centrin/Zone analysis/BB measurements cell 17/Zone 2/single_gaussian_fit_parameters.csv')
cell19_zone1 = pd.read_csv('W:/Users/Daphne/WT_RESULTS/WT_ExM_Centrin/Zone analysis/BB measurements cell 19/Zone 1/single_gaussian_fit_parameters.csv')
cell19_zone2 = pd.read_csv('W:/Users/Daphne/WT_RESULTS/WT_ExM_Centrin/Zone analysis/BB measurements cell 19/Zone 2/single_gaussian_fit_parameters.csv')
cell20_zone1 = pd.read_csv('W:/Users/Daphne/WT_RESULTS/WT_ExM_Centrin/Zone analysis/BB measurements cell 20/Zone 1/single_gaussian_fit_parameters.csv')
cell20_zone2 = pd.read_csv('W:/Users/Daphne/WT_RESULTS/WT_ExM_Centrin/Zone analysis/BB measurements cell 20/Zone 2/single_gaussian_fit_parameters.csv')
cell23_zone1 = pd.read_csv('W:/Users/Daphne/WT_RESULTS/WT_ExM_Centrin/Zone analysis/BB measurements cell 23/Zone 1/single_gaussian_fit_parameters.csv')
cell23_zone2 = pd.read_csv('W:/Users/Daphne/WT_RESULTS/WT_ExM_Centrin/Zone analysis/BB measurements cell 23/Zone 2/single_gaussian_fit_parameters.csv')
cell24_zone1 = pd.read_csv('W:/Users/Daphne/WT_RESULTS/WT_ExM_Centrin/Zone analysis/BB measurements cell 24/Zone 1/single_gaussian_fit_parameters.csv')
cell24_zone2 = pd.read_csv('W:/Users/Daphne/WT_RESULTS/WT_ExM_Centrin/Zone analysis/BB measurements cell 24/Zone 2/single_gaussian_fit_parameters.csv')

# %%
# Take from each cell (exclude doublets) the "Mean" and "Standard deviation" rows and put them in a new dataframe
cell5_zone1_mean = cell5_zone1.loc[0]
cell5_zone1_std = cell5_zone1.loc[1]
cell5_zone2_mean = cell5_zone2.loc[0]
cell5_zone2_std = cell5_zone2.loc[1]

cell6_zone1_mean = cell6_zone1.loc[0]
cell6_zone1_std = cell6_zone1.loc[1]
cell6_zone2_mean = cell6_zone2.loc[0]
cell6_zone2_std = cell6_zone2.loc[1]

cell7_zone1_mean = cell7_zone1.loc[0]
cell7_zone1_std = cell7_zone1.loc[1]
cell7_zone2_mean = cell7_zone2.loc[0]
cell7_zone2_std = cell7_zone2.loc[1]

cell10_zone1_mean = cell10_zone1.loc[0]
cell10_zone1_std = cell10_zone1.loc[1]
cell10_zone2_mean = cell10_zone2.loc[0]
cell10_zone2_std = cell10_zone2.loc[1]

cell11_zone1_mean = cell11_zone1.loc[0]
cell11_zone1_std = cell11_zone1.loc[1]
cell11_zone2_mean = cell11_zone2.loc[0]
cell11_zone2_std = cell11_zone2.loc[1]
cell17_zone1_mean = cell17_zone1.loc[0]
cell17_zone1_std = cell17_zone1.loc[1]
cell17_zone2_mean = cell17_zone2.loc[0]
cell17_zone2_std = cell17_zone2.loc[1]
cell19_zone1_mean = cell19_zone1.loc[0]
cell19_zone1_std = cell19_zone1.loc[1]
cell19_zone2_mean = cell19_zone2.loc[0]
cell19_zone2_std = cell19_zone2.loc[1]
cell20_zone1_mean = cell20_zone1.loc[0]
cell20_zone1_std = cell20_zone1.loc[1]
cell20_zone2_mean = cell20_zone2.loc[0]
cell20_zone2_std = cell20_zone2.loc[1]
cell23_zone1_mean = cell23_zone1.loc[0]
cell23_zone1_std = cell23_zone1.loc[1]
cell23_zone2_mean = cell23_zone2.loc[0]
cell23_zone2_std = cell23_zone2.loc[1]
cell24_zone1_mean = cell24_zone1.loc[0]
cell24_zone1_std = cell24_zone1.loc[1]
cell24_zone2_mean = cell24_zone2.loc[0]
cell24_zone2_std = cell24_zone2.loc[1]

# %%
# Make a boxplot to compare the mean values between zones
# Add cells together to later compare the mean values between zones
# zone1_mean = pd.concat([cell5_zone1_mean, cell6_zone1_mean, cell7_zone1_mean, cell10_zone1_mean], axis=1)
# zone2_mean = pd.concat([cell5_zone2_mean, cell6_zone2_mean, cell7_zone2_mean, cell10_zone2_mean], axis=1)
zone1_mean = pd.concat([cell5_zone1_mean, cell6_zone1_mean, cell7_zone1_mean, cell10_zone1_mean, cell11_zone1_mean, cell17_zone1_mean, cell19_zone1_mean, cell20_zone1_mean, cell23_zone1_mean, cell24_zone1_mean], axis=1)
zone2_mean = pd.concat([cell5_zone2_mean, cell6_zone2_mean, cell7_zone2_mean, cell10_zone2_mean, cell11_zone2_mean, cell17_zone2_mean, cell19_zone2_mean, cell20_zone2_mean, cell23_zone2_mean, cell24_zone2_mean], axis=1)

zone1_mean = zone1_mean.T
zone2_mean = zone2_mean.T

zone1_mean = zone1_mean.values
zone2_mean = zone2_mean.values

zone1_mean = zone1_mean[:,1]
zone2_mean = zone2_mean[:,1]

# Create a DataFrame for seaborn
df_mean = pd.DataFrame({
    'Value': np.concatenate([zone1_mean, zone2_mean]),
    'Group': ['Doublets'] * len(zone1_mean) + ['Singlets'] * len(zone2_mean)
})

# Set dark background style
plt.style.use('dark_background')
sns.set_style('dark')

boxprops = dict(edgecolor='white', linewidth=1.5)
whiskerprops = dict(color='white', linewidth=1.2)
capprops = dict(color='white', linewidth=1.2)
medianprops = dict(color='white', linewidth=1.5)


# Plot the data
plt.figure(figsize=(5, 6))
sns.boxplot(x='Group', y='Value', data=df_mean, palette=['yellow', 'cyan'], boxprops=boxprops, whiskerprops=whiskerprops, capprops=capprops, medianprops=medianprops, linewidth=1.5, showfliers=False)
sns.stripplot(x='Group', y='Value', data=df_mean, color='red', alpha=0.6, jitter=True, dodge=True, size=6, edgecolor='black')
plt.title('Cilia spacing within rows', fontsize=24, color='white')
plt.ylabel('µm', fontsize=22, color='white')
plt.ylim(1.4, 2.6)
plt.xlabel(None)
plt.xticks(fontsize=18, color='white')
plt.yticks(fontsize=18, color='white')
plt.gca().set_facecolor('black')
plt.grid(True, axis='y', color='white', linewidth=0.5, alpha=0.5)
plt.tight_layout()
plt.savefig('comparison_mean_bb_distance_WT.png', dpi=300)
plt.savefig('comparison_mean_bb_distance_WT.svg', format='svg')
plt.show()

# Save the DataFrame to a CSV file
df_mean.to_csv('comparison_mean_bb_distance_WT.csv', index=False)
# Out:
# C:\Users\laan\AppData\Local\Temp\ipykernel_41616\3487841699.py:35: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Group', y='Value', data=df_mean, palette=['yellow', 'cyan'], boxprops=boxprops, whiskerprops=whiskerprops, capprops=capprops, medianprops=medianprops, linewidth=1.5, showfliers=False)

# %%
# WHITE BACKGROUND
# Make a boxplot to compare the mean values between zones
# Add cells together to later compare the mean values between zones
# zone1_mean = pd.concat([cell5_zone1_mean, cell6_zone1_mean, cell7_zone1_mean, cell10_zone1_mean], axis=1)
# zone2_mean = pd.concat([cell5_zone2_mean, cell6_zone2_mean, cell7_zone2_mean, cell10_zone2_mean], axis=1)
zone1_mean = pd.concat([cell5_zone1_mean, cell6_zone1_mean, cell7_zone1_mean, cell10_zone1_mean, cell11_zone1_mean, cell17_zone1_mean, cell19_zone1_mean, cell20_zone1_mean, cell23_zone1_mean, cell24_zone1_mean], axis=1)
zone2_mean = pd.concat([cell5_zone2_mean, cell6_zone2_mean, cell7_zone2_mean, cell10_zone2_mean, cell11_zone2_mean, cell17_zone2_mean, cell19_zone2_mean, cell20_zone2_mean, cell23_zone2_mean, cell24_zone2_mean], axis=1)

zone1_mean = zone1_mean.T
zone2_mean = zone2_mean.T

zone1_mean = zone1_mean.values
zone2_mean = zone2_mean.values

zone1_mean = zone1_mean[:,1]
zone2_mean = zone2_mean[:,1]

# Create a DataFrame for seaborn
df_mean = pd.DataFrame({
    'Value': np.concatenate([zone1_mean, zone2_mean]),
    'Group': ['Doublets'] * len(zone1_mean) + ['Singlets'] * len(zone2_mean)
})

import matplotlib.pyplot as plt
import seaborn as sns

# Set white background style
plt.style.use('default')
sns.set_style('whitegrid')

# Boxplot styling (black edges instead of white)
boxprops = dict(edgecolor='black', linewidth=1.5)
whiskerprops = dict(color='black', linewidth=1.2)
capprops = dict(color='black', linewidth=1.2)
medianprops = dict(color='black', linewidth=1.5)

# Plot the data
plt.figure(figsize=(5, 6), facecolor='white')
ax = plt.subplot(1, 1, 1, facecolor='white')

sns.boxplot(
    x='Group',
    y='Value',
    data=df_mean,
    palette=['yellow', 'cyan'],
    boxprops=boxprops,
    whiskerprops=whiskerprops,
    capprops=capprops,
    medianprops=medianprops,
    linewidth=1.5,
    showfliers=False,
    ax=ax
)

sns.stripplot(
    x='Group',
    y='Value',
    data=df_mean,
    color='red',
    alpha=0.6,
    jitter=True,
    dodge=True,
    size=6,
    edgecolor='black',
    ax=ax
)

# Labels and title (black instead of white)
plt.title('Cilia spacing within rows', fontsize=24, color='black')
plt.ylabel('µm', fontsize=22, color='black')
plt.ylim(1.4, 2.6)
plt.xlabel(None)
plt.xticks(fontsize=18, color='black')
plt.yticks(fontsize=18, color='black')
plt.gca().set_facecolor('white')

# Grid in subtle black
plt.grid(True, axis='y', color='black', linewidth=0.5, alpha=0.3)

# Add black border around plot
for spine in ax.spines.values():
    spine.set_edgecolor("black")
    spine.set_linewidth(1.5)

plt.tight_layout()
plt.savefig('comparison_mean_bb_distance_WT_BW.png', dpi=300, facecolor='white')
plt.savefig('comparison_mean_bb_distance_WT_BW.svg', format='svg', facecolor='white')
plt.show()

# Save the DataFrame to a CSV file
df_mean.to_csv('comparison_mean_bb_distance_WT.csv', index=False)
# Out:
# C:\Users\laan\AppData\Local\Temp\ipykernel_41616\3651369782.py:41: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(

# %%
# Make a boxplot to compare the standard deviation between zones
zone1_std = pd.concat([cell5_zone1_std, cell6_zone1_std, cell7_zone1_std, cell10_zone1_std], axis=1)
zone2_std = pd.concat([cell5_zone2_std, cell6_zone2_std, cell7_zone2_std, cell10_zone2_std], axis=1)
zone1_std = zone1_std.T
zone2_std = zone2_std.T

zone1_std = zone1_std.values
zone2_std = zone2_std.values

zone1_std = zone1_std[:,1]
zone2_std = zone2_std[:,1]

# Create a DataFrame for seaborn
df_std = pd.DataFrame({
    'Value': np.concatenate([zone1_std, zone2_std]),
    'Group': ['Zone 1'] * len(zone1_std) + ['Zone 2'] * len(zone2_std)
})

# Plot the data
plt.figure(figsize=(5, 6))
sns.boxplot(x='Group', y='Value', data=df_std, palette=['yellow', 'cyan'], linewidth=2)
sns.stripplot(x='Group', y='Value', data=df_std, color='red', alpha=0.5, jitter=True)
plt.title('Standard Deviation BB distance', fontsize=16)
plt.ylabel('BB distance (\u03BCm)', fontsize=14)
plt.xlabel('Zone', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.savefig('comparison_std_bb_distance_WT.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# C:\Users\laan\AppData\Local\Temp\ipykernel_29492\1444174684.py:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Group', y='Value', data=df_std, palette=['yellow', 'cyan'], linewidth=2, ax=ax, whiskerprops=dict(color='white'), capprops=dict(color='white'), medianprops=dict(color='white'))

# %% [markdown]
# ## ALL conditions

# %%
# control_data, Load the CSV files for each cell and zone
control_cell1_zone1 = pd.read_csv('W:/Users/Daphne/DATA FOR APS/control_data/control_IF/polye_channels/BB measurements cell 1/Zone 1/single_gaussian_fit_parameters.csv')
control_cell1_zone2 = pd.read_csv('W:/Users/Daphne/DATA FOR APS/control_data/control_IF/polye_channels/BB measurements cell 1/Zone 2/single_gaussian_fit_parameters.csv')
control_cell2_zone1 = pd.read_csv('W:/Users/Daphne/DATA FOR APS/control_data/control_IF/polye_channels/BB measurements cell 2/Zone 1/single_gaussian_fit_parameters.csv')
control_cell2_zone2 = pd.read_csv('W:/Users/Daphne/DATA FOR APS/control_data/control_IF/polye_channels/BB measurements cell 2/Zone 2/single_gaussian_fit_parameters.csv')
control_cell3_zone1 = pd.read_csv('W:/Users/Daphne/DATA FOR APS/control_data/control_IF/polye_channels/BB measurements cell 3/Zone 1/single_gaussian_fit_parameters.csv')
control_cell4_zone2 = pd.read_csv('W:/Users/Daphne/DATA FOR APS/control_data/control_IF/polye_channels/BB measurements cell 4/Zone 2/single_gaussian_fit_parameters.csv')
control_cell5_zone1 = pd.read_csv('W:/Users/Daphne/DATA FOR APS/control_data/control_IF/polye_channels/BB measurements cell 5/Zone 1/single_gaussian_fit_parameters.csv')
control_cell6_zone2 = pd.read_csv('W:/Users/Daphne/DATA FOR APS/control_data/control_IF/polye_channels/BB measurements cell 6/Zone 2/single_gaussian_fit_parameters.csv')

# Take from each cell the "Mean" and "Standard deviation" rows and put them in a new dataframe
control_cell1_zone1_mean = control_cell1_zone1.loc[0]
control_cell1_zone1_std = control_cell1_zone1.loc[1]
control_cell1_zone2_mean = control_cell1_zone2.loc[0]
control_cell1_zone2_std = control_cell1_zone2.loc[1]
control_cell2_zone1_mean = control_cell2_zone1.loc[0]
control_cell2_zone1_std = control_cell2_zone1.loc[1]
control_cell2_zone2_mean = control_cell2_zone2.loc[0]
control_cell2_zone2_std = control_cell2_zone2.loc[1]
control_cell3_zone1_mean = control_cell3_zone1.loc[0]
control_cell3_zone1_std = control_cell3_zone1.loc[1]
control_cell4_zone2_mean = control_cell4_zone2.loc[0]
control_cell4_zone2_std = control_cell4_zone2.loc[1]
control_cell5_zone1_mean = control_cell5_zone1.loc[0]
control_cell5_zone1_std = control_cell5_zone1.loc[1]
control_cell6_zone2_mean = control_cell6_zone2.loc[0]
control_cell6_zone2_std = control_cell6_zone2.loc[1]

# Add cells together to later compare the mean values between zones
control_zone1_mean = pd.concat([control_cell1_zone1_mean, control_cell2_zone1_mean, control_cell3_zone1_mean, control_cell5_zone1_mean], axis=1)
control_zone2_mean = pd.concat([control_cell1_zone2_mean, control_cell2_zone2_mean, control_cell4_zone2_mean, control_cell6_zone2_mean], axis=1)
control_zone1_mean = control_zone1_mean.T
control_zone2_mean = control_zone2_mean.T
control_zone1_mean = control_zone1_mean.values
control_zone2_mean = control_zone2_mean.values

control_zone1_mean = control_zone1_mean[:,1]
control_zone2_mean = control_zone2_mean[:,1]

# Create a DataFrame for seaborn
df_control_mean = pd.DataFrame({
    'Value': np.concatenate([control_zone1_mean, control_zone2_mean]),
    'Group': ['Zone 1'] * len(control_zone1_mean) + ['Zone 2'] * len(control_zone2_mean)
})

# Add cells together to later compare the standard deviation between zones
control_zone1_std = pd.concat([control_cell1_zone1_std, control_cell2_zone1_std, control_cell3_zone1_std, control_cell5_zone1_std], axis=1)
control_zone2_std = pd.concat([control_cell1_zone2_std, control_cell2_zone2_std, control_cell4_zone2_std, control_cell6_zone2_std], axis=1)
control_zone1_std = control_zone1_std.T
control_zone2_std = control_zone2_std.T
control_zone1_std = control_zone1_std.values
control_zone2_std = control_zone2_std.values

control_zone1_std = control_zone1_std[:,1]
control_zone2_std = control_zone2_std[:,1]

# Create a DataFrame for seaborn
df_control_std = pd.DataFrame({
    'Value': np.concatenate([control_zone1_std, control_zone2_std]),
    'Group': ['Zone 1'] * len(control_zone1_std) + ['Zone 2'] * len(control_zone2_std)
})

# %%
# SF7a_data, Load the CSV files for each cell and zone
SF7a_cell1_zone1 = pd.read_csv('W:/Users/Daphne/DATA FOR APS/SF7a_data/SF7a_IF/polye_channels/BB measurements cell 1/Zone 1/single_gaussian_fit_parameters.csv')
SF7a_cell1_zone2 = pd.read_csv('W:/Users/Daphne/DATA FOR APS/SF7a_data/SF7a_IF/polye_channels/BB measurements cell 1/Zone 2/single_gaussian_fit_parameters.csv')
SF7a_cell2_zone1 = pd.read_csv('W:/Users/Daphne/DATA FOR APS/SF7a_data/SF7a_IF/polye_channels/BB measurements cell 2/Zone 1/single_gaussian_fit_parameters.csv')
SF7a_cell2_zone2 = pd.read_csv('W:/Users/Daphne/DATA FOR APS/SF7a_data/SF7a_IF/polye_channels/BB measurements cell 2/Zone 2/single_gaussian_fit_parameters.csv')
SF7a_cell3_zone1 = pd.read_csv('W:/Users/Daphne/DATA FOR APS/SF7a_data/SF7a_IF/polye_channels/BB measurements cell 3/Zone 1/single_gaussian_fit_parameters.csv')
SF7a_cell3_zone2 = pd.read_csv('W:/Users/Daphne/DATA FOR APS/SF7a_data/SF7a_IF/polye_channels/BB measurements cell 3/Zone 2/single_gaussian_fit_parameters.csv')
SF7a_cell4_zone1 = pd.read_csv('W:/Users/Daphne/DATA FOR APS/SF7a_data/SF7a_IF/polye_channels/BB measurements cell 4/Zone 1/single_gaussian_fit_parameters.csv')
SF7a_cell4_zone2 = pd.read_csv('W:/Users/Daphne/DATA FOR APS/SF7a_data/SF7a_IF/polye_channels/BB measurements cell 4/Zone 2/single_gaussian_fit_parameters.csv')

# Take from each cell the "Mean" and "Standard deviation" rows and put them in a new dataframe
SF7a_cell1_zone1_mean = SF7a_cell1_zone1.loc[0]
SF7a_cell1_zone1_std = SF7a_cell1_zone1.loc[1]
SF7a_cell1_zone2_mean = SF7a_cell1_zone2.loc[0]
SF7a_cell1_zone2_std = SF7a_cell1_zone2.loc[1]
SF7a_cell2_zone1_mean = SF7a_cell2_zone1.loc[0]
SF7a_cell2_zone1_std = SF7a_cell2_zone1.loc[1]
SF7a_cell2_zone2_mean = SF7a_cell2_zone2.loc[0]
SF7a_cell2_zone2_std = SF7a_cell2_zone2.loc[1]
SF7a_cell3_zone1_mean = SF7a_cell3_zone1.loc[0]
SF7a_cell3_zone1_std = SF7a_cell3_zone1.loc[1]
SF7a_cell3_zone2_mean = SF7a_cell3_zone2.loc[0]
SF7a_cell3_zone2_std = SF7a_cell3_zone2.loc[1]
SF7a_cell4_zone1_mean = SF7a_cell4_zone1.loc[0]
SF7a_cell4_zone1_std = SF7a_cell4_zone1.loc[1]
SF7a_cell4_zone2_mean = SF7a_cell4_zone2.loc[0]
SF7a_cell4_zone2_std = SF7a_cell4_zone2.loc[1]

# Add cells together to later compare the mean values between zones
SF7a_zone1_mean = pd.concat([SF7a_cell1_zone1_mean, SF7a_cell2_zone1_mean, SF7a_cell3_zone1_mean, SF7a_cell4_zone1_mean], axis=1)
SF7a_zone2_mean = pd.concat([SF7a_cell1_zone2_mean, SF7a_cell2_zone2_mean, SF7a_cell3_zone2_mean, SF7a_cell4_zone2_mean], axis=1)
SF7a_zone1_mean = SF7a_zone1_mean.T
SF7a_zone2_mean = SF7a_zone2_mean.T
SF7a_zone1_mean = SF7a_zone1_mean.values
SF7a_zone2_mean = SF7a_zone2_mean.values

SF7a_zone1_mean = SF7a_zone1_mean[:,1]
SF7a_zone2_mean = SF7a_zone2_mean[:,1]

# Create a DataFrame for seaborn
df_SF7a_mean = pd.DataFrame({
    'Value': np.concatenate([SF7a_zone1_mean, SF7a_zone2_mean]),
    'Group': ['Zone 1'] * len(SF7a_zone1_mean) + ['Zone 2'] * len(SF7a_zone2_mean)
})

# Add cells together to later compare the standard deviation between zones
SF7a_zone1_std = pd.concat([SF7a_cell1_zone1_std, SF7a_cell2_zone1_std, SF7a_cell3_zone1_std, SF7a_cell4_zone1_std], axis=1)
SF7a_zone2_std = pd.concat([SF7a_cell1_zone2_std, SF7a_cell2_zone2_std, SF7a_cell3_zone2_std, SF7a_cell4_zone2_std], axis=1)
SF7a_zone1_std = SF7a_zone1_std.T
SF7a_zone2_std = SF7a_zone2_std.T
SF7a_zone1_std = SF7a_zone1_std.values
SF7a_zone2_std = SF7a_zone2_std.values

SF7a_zone1_std = SF7a_zone1_std[:,1]
SF7a_zone2_std = SF7a_zone2_std[:,1]

# Create a DataFrame for seaborn
df_SF7a_std = pd.DataFrame({
    'Value': np.concatenate([SF7a_zone1_std, SF7a_zone2_std]),
    'Group': ['Zone 1'] * len(SF7a_zone1_std) + ['Zone 2'] * len(SF7a_zone2_std)
})

# %%
# ICL10_data, Load the CSV files for each cell and zone
ICL10_cell1_zone1 = pd.read_csv('W:/Users/Daphne/DATA FOR APS/ICL10_data/ICL10_IF/polye_channels/BB measurements cell 1/Zone 1/single_gaussian_fit_parameters.csv')
ICL10_cell1_zone2 = pd.read_csv('W:/Users/Daphne/DATA FOR APS/ICL10_data/ICL10_IF/polye_channels/BB measurements cell 1/Zone 2/single_gaussian_fit_parameters.csv')
ICL10_cell2_zone1 = pd.read_csv('W:/Users/Daphne/DATA FOR APS/ICL10_data/ICL10_IF/polye_channels/BB measurements cell 2/Zone 1/single_gaussian_fit_parameters.csv')
ICL10_cell2_zone2 = pd.read_csv('W:/Users/Daphne/DATA FOR APS/ICL10_data/ICL10_IF/polye_channels/BB measurements cell 2/Zone 2/single_gaussian_fit_parameters.csv')
ICL10_cell3_zone1 = pd.read_csv('W:/Users/Daphne/DATA FOR APS/ICL10_data/ICL10_IF/polye_channels/BB measurements cell 3/Zone 1/single_gaussian_fit_parameters.csv')
ICL10_cell3_zone2 = pd.read_csv('W:/Users/Daphne/DATA FOR APS/ICL10_data/ICL10_IF/polye_channels/BB measurements cell 3/Zone 2/single_gaussian_fit_parameters.csv')
ICL10_cell4_zone1 = pd.read_csv('W:/Users/Daphne/DATA FOR APS/ICL10_data/ICL10_IF/polye_channels/BB measurements cell 4/Zone 1/single_gaussian_fit_parameters.csv')
ICL10_cell4_zone2 = pd.read_csv('W:/Users/Daphne/DATA FOR APS/ICL10_data/ICL10_IF/polye_channels/BB measurements cell 4/Zone 2/single_gaussian_fit_parameters.csv')

# Take from each cell the "Mean" and "Standard deviation" rows and put them in a new dataframe
ICL10_cell1_zone1_mean = ICL10_cell1_zone1.loc[0]
ICL10_cell1_zone1_std = ICL10_cell1_zone1.loc[1]
ICL10_cell1_zone2_mean = ICL10_cell1_zone2.loc[0]
ICL10_cell1_zone2_std = ICL10_cell1_zone2.loc[1]
ICL10_cell2_zone1_mean = ICL10_cell2_zone1.loc[0]
ICL10_cell2_zone1_std = ICL10_cell2_zone1.loc[1]
ICL10_cell2_zone2_mean = ICL10_cell2_zone2.loc[0]
ICL10_cell2_zone2_std = ICL10_cell2_zone2.loc[1]
ICL10_cell3_zone1_mean = ICL10_cell3_zone1.loc[0]
ICL10_cell3_zone1_std = ICL10_cell3_zone1.loc[1]
ICL10_cell3_zone2_mean = ICL10_cell3_zone2.loc[0]
ICL10_cell3_zone2_std = ICL10_cell3_zone2.loc[1]
ICL10_cell4_zone1_mean = ICL10_cell4_zone1.loc[0]
ICL10_cell4_zone1_std = ICL10_cell4_zone1.loc[1]
ICL10_cell4_zone2_mean = ICL10_cell4_zone2.loc[0]
ICL10_cell4_zone2_std = ICL10_cell4_zone2.loc[1]

# Add cells together to later compare the mean values between zones
ICL10_zone1_mean = pd.concat([ICL10_cell1_zone1_mean, ICL10_cell2_zone1_mean, ICL10_cell3_zone1_mean, ICL10_cell4_zone1_mean], axis=1)
ICL10_zone2_mean = pd.concat([ICL10_cell1_zone2_mean, ICL10_cell2_zone2_mean, ICL10_cell3_zone2_mean, ICL10_cell4_zone2_mean], axis=1)
ICL10_zone1_mean = ICL10_zone1_mean.T
ICL10_zone2_mean = ICL10_zone2_mean.T
ICL10_zone1_mean = ICL10_zone1_mean.values
ICL10_zone2_mean = ICL10_zone2_mean.values

ICL10_zone1_mean = ICL10_zone1_mean[:,1]
ICL10_zone2_mean = ICL10_zone2_mean[:,1]

# Create a DataFrame for seaborn
df_ICL10_mean = pd.DataFrame({
    'Value': np.concatenate([ICL10_zone1_mean, ICL10_zone2_mean]),
    'Group': ['Zone 1'] * len(ICL10_zone1_mean) + ['Zone 2'] * len(ICL10_zone2_mean)
})

# Add cells together to later compare the standard deviation between zones
ICL10_zone1_std = pd.concat([ICL10_cell1_zone1_std, ICL10_cell2_zone1_std, ICL10_cell3_zone1_std, ICL10_cell4_zone1_std], axis=1)
ICL10_zone2_std = pd.concat([ICL10_cell1_zone2_std, ICL10_cell2_zone2_std, ICL10_cell3_zone2_std, ICL10_cell4_zone2_std], axis=1)
ICL10_zone1_std = ICL10_zone1_std.T
ICL10_zone2_std = ICL10_zone2_std.T
ICL10_zone1_std = ICL10_zone1_std.values
ICL10_zone2_std = ICL10_zone2_std.values

ICL10_zone1_std = ICL10_zone1_std[:,1]
ICL10_zone2_std = ICL10_zone2_std[:,1]

# Create a DataFrame for seaborn
df_ICL10_std = pd.DataFrame({
    'Value': np.concatenate([ICL10_zone1_std, ICL10_zone2_std]),
    'Group': ['Zone 1'] * len(ICL10_zone1_std) + ['Zone 2'] * len(ICL10_zone2_std)
})

# %%
# ICL11_data, Load the CSV files for each cell and zone
ICL11_cell1_zone1 = pd.read_csv('W:/Users/Daphne/DATA FOR APS/ICL11_data/ICL11_IF/polye_channels/BB measurements cell 1/Zone 1/single_gaussian_fit_parameters.csv')
ICL11_cell1_zone2 = pd.read_csv('W:/Users/Daphne/DATA FOR APS/ICL11_data/ICL11_IF/polye_channels/BB measurements cell 1/Zone 2/single_gaussian_fit_parameters.csv')
ICL11_cell2_zone1 = pd.read_csv('W:/Users/Daphne/DATA FOR APS/ICL11_data/ICL11_IF/polye_channels/BB measurements cell 2/Zone 1/single_gaussian_fit_parameters.csv')
ICL11_cell2_zone2 = pd.read_csv('W:/Users/Daphne/DATA FOR APS/ICL11_data/ICL11_IF/polye_channels/BB measurements cell 2/Zone 2/single_gaussian_fit_parameters.csv')
ICL11_cell3_zone1 = pd.read_csv('W:/Users/Daphne/DATA FOR APS/ICL11_data/ICL11_IF/polye_channels/BB measurements cell 3/Zone 1/single_gaussian_fit_parameters.csv')
ICL11_cell3_zone2 = pd.read_csv('W:/Users/Daphne/DATA FOR APS/ICL11_data/ICL11_IF/polye_channels/BB measurements cell 3/Zone 2/single_gaussian_fit_parameters.csv')

# Take from each cell the "Mean" and "Standard deviation" rows and put them in a new dataframe
ICL11_cell1_zone1_mean = ICL11_cell1_zone1.loc[0]
ICL11_cell1_zone1_std = ICL11_cell1_zone1.loc[1]
ICL11_cell1_zone2_mean = ICL11_cell1_zone2.loc[0]
ICL11_cell1_zone2_std = ICL11_cell1_zone2.loc[1]
ICL11_cell2_zone1_mean = ICL11_cell2_zone1.loc[0]
ICL11_cell2_zone1_std = ICL11_cell2_zone1.loc[1]
ICL11_cell2_zone2_mean = ICL11_cell2_zone2.loc[0]
ICL11_cell2_zone2_std = ICL11_cell2_zone2.loc[1]
ICL11_cell3_zone1_mean = ICL11_cell3_zone1.loc[0]
ICL11_cell3_zone1_std = ICL11_cell3_zone1.loc[1]
ICL11_cell3_zone2_mean = ICL11_cell3_zone2.loc[0]
ICL11_cell3_zone2_std = ICL11_cell3_zone2.loc[1]

# Add cells together to later compare the mean values between zones
ICL11_zone1_mean = pd.concat([ICL11_cell1_zone1_mean, ICL11_cell2_zone1_mean, ICL11_cell3_zone1_mean], axis=1)
ICL11_zone2_mean = pd.concat([ICL11_cell1_zone2_mean, ICL11_cell2_zone2_mean, ICL11_cell3_zone2_mean], axis=1)
ICL11_zone1_mean = ICL11_zone1_mean.T
ICL11_zone2_mean = ICL11_zone2_mean.T
ICL11_zone1_mean = ICL11_zone1_mean.values
ICL11_zone2_mean = ICL11_zone2_mean.values

ICL11_zone1_mean = ICL11_zone1_mean[:,1]
ICL11_zone2_mean = ICL11_zone2_mean[:,1]

# Create a DataFrame for seaborn
df_ICL11_mean = pd.DataFrame({
    'Value': np.concatenate([ICL11_zone1_mean, ICL11_zone2_mean]),
    'Group': ['Zone 1'] * len(ICL11_zone1_mean) + ['Zone 2'] * len(ICL11_zone2_mean)
})

# Add cells together to later compare the standard deviation between zones
ICL11_zone1_std = pd.concat([ICL11_cell1_zone1_std, ICL11_cell2_zone1_std, ICL11_cell3_zone1_std], axis=1)
ICL11_zone2_std = pd.concat([ICL11_cell1_zone2_std, ICL11_cell2_zone2_std, ICL11_cell3_zone2_std], axis=1)
ICL11_zone1_std = ICL11_zone1_std.T
ICL11_zone2_std = ICL11_zone2_std.T
ICL11_zone1_std = ICL11_zone1_std.values
ICL11_zone2_std = ICL11_zone2_std.values

ICL11_zone1_std = ICL11_zone1_std[:,1]
ICL11_zone2_std = ICL11_zone2_std[:,1]

# Create a DataFrame for seaborn
df_ICL11_std = pd.DataFrame({
    'Value': np.concatenate([ICL11_zone1_std, ICL11_zone2_std]),
    'Group': ['Zone 1'] * len(ICL11_zone1_std) + ['Zone 2'] * len(ICL11_zone2_std)
})

# %%
# # Create a dataframe with all conditions to plot them together
#
# # Create a DataFrame for seaborn
# df_all_conditions_mean = pd.DataFrame({
#     'Value': np.concatenate([control_zone1_mean, control_zone2_mean, SF7a_zone1_mean, SF7a_zone2_mean, ICL10_zone1_mean, ICL10_zone2_mean, ICL11_zone1_mean, ICL11_zone2_mean]),
#     'Condition': ['Control'] * len(control_zone1_mean) + ['Control'] * len(control_zone2_mean) +
#                  ['SF7a'] * len(SF7a_zone1_mean) + ['SF7a'] * len(SF7a_zone2_mean) +
#                  ['ICL10'] * len(ICL10_zone1_mean) + ['ICL10'] * len(ICL10_zone2_mean) +
#                  ['ICL11'] * len(ICL11_zone1_mean) + ['ICL11'] * len(ICL11_zone2_mean),
#     'Group': ['Zone 1'] * len(control_zone1_mean) + ['Zone 2'] * len(control_zone2_mean) +
#              ['Zone 1'] * len(SF7a_zone1_mean) + ['Zone 2'] * len(SF7a_zone2_mean) +
#              ['Zone 1'] * len(ICL10_zone1_mean) + ['Zone 2'] * len(ICL10_zone2_mean) +
#              ['Zone 1'] * len(ICL11_zone1_mean) + ['Zone 2'] * len(ICL11_zone2_mean)
# })
#
# # Plot the data
# plt.figure(figsize=(12, 8))
# sns.boxplot(x='Condition', y='Value', hue='Group', data=df_all_conditions_mean, palette='Set3')
# sns.stripplot(x='Condition', y='Value', hue='Group', data=df_all_conditions_mean, color='red', alpha=0.5, jitter=True)
# plt.title('Comparison of Mean BB distance across all conditions')
# plt.ylabel('BB distance (\u03BCm)')
# plt.savefig('comparison_mean_bb_distance_all_conditions.png', dpi=300, bbox_inches='tight')
# plt.show()

# %%
# Create a DataFrame for seaborn
df_all_conditions_mean = pd.DataFrame({
    'Value': np.concatenate([zone1_mean, zone2_mean, control_zone1_mean, control_zone2_mean, SF7a_zone1_mean, SF7a_zone2_mean, ICL10_zone1_mean, ICL10_zone2_mean, ICL11_zone1_mean, ICL11_zone2_mean]),
    'Condition': ['WT'] * len(zone1_mean) + ['WT'] * len(zone2_mean) +
                 ['Control'] * len(control_zone1_mean) + ['Control'] * len(control_zone2_mean) +
                 ['SF7a'] * len(SF7a_zone1_mean) + ['SF7a'] * len(SF7a_zone2_mean) +
                 ['ICL10'] * len(ICL10_zone1_mean) + ['ICL10'] * len(ICL10_zone2_mean) +
                 ['ICL11'] * len(ICL11_zone1_mean) + ['ICL11'] * len(ICL11_zone2_mean),
    'Group': ['Zone 1'] * len(zone1_mean) + ['Zone 2'] * len(zone2_mean) +
             ['Zone 1'] * len(control_zone1_mean) + ['Zone 2'] * len(control_zone2_mean) +
             ['Zone 1'] * len(SF7a_zone1_mean) + ['Zone 2'] * len(SF7a_zone2_mean) +
             ['Zone 1'] * len(ICL10_zone1_mean) + ['Zone 2'] * len(ICL10_zone2_mean) +
             ['Zone 1'] * len(ICL11_zone1_mean) + ['Zone 2'] * len(ICL11_zone2_mean),
})

# Plot the data
plt.figure(figsize=(12, 8))
sns.set_theme(style="white")
sns.boxplot(x='Condition', y='Value', hue='Group', data=df_all_conditions_mean, palette=['yellow', 'cyan'], linewidth=2)
sns.stripplot(x='Condition', y='Value', hue='Group', data=df_all_conditions_mean, palette=['red', 'red'], dodge=True, alpha=0.5, jitter=True)
plt.title('Mean basal body distance', fontsize=16)
plt.xlabel('Condition', fontsize=14)
plt.ylabel('BB distance (\u03BCm)', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
handles, labels = plt.gca().get_legend_handles_labels()
plt.legend(handles[0:2], labels[0:2], fontsize=12)
plt.savefig('comparison_mean_bb_distance_all_conditions.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# Create a DataFrame for seaborn for the standard deviation
df_all_conditions_std = pd.DataFrame({
    'Value': np.concatenate([zone1_std, zone2_std, control_zone1_std, control_zone2_std, SF7a_zone1_std, SF7a_zone2_std, ICL10_zone1_std, ICL10_zone2_std, ICL11_zone1_std, ICL11_zone2_std]),
    'Condition': ['WT'] * len(zone1_std) + ['WT'] * len(zone2_std) +
                 ['Control'] * len(control_zone1_std) + ['Control'] * len(control_zone2_std) +
                 ['SF7a'] * len(SF7a_zone1_std) + ['SF7a'] * len(SF7a_zone2_std) +
                 ['ICL10'] * len(ICL10_zone1_std) + ['ICL10'] * len(ICL10_zone2_std) +
                 ['ICL11'] * len(ICL11_zone1_std) + ['ICL11'] * len(ICL11_zone2_std),
    'Group': ['Zone 1'] * len(zone1_std) + ['Zone 2'] * len(zone2_std) +
             ['Zone 1'] * len(control_zone1_std) + ['Zone 2'] * len(control_zone2_std) +
             ['Zone 1'] * len(SF7a_zone1_std) + ['Zone 2'] * len(SF7a_zone2_std) +
             ['Zone 1'] * len(ICL10_zone1_std) + ['Zone 2'] * len(ICL10_zone2_std) +
             ['Zone 1'] * len(ICL11_zone1_std) + ['Zone 2'] * len(ICL11_zone2_std),
})

# Plot the data
plt.figure(figsize=(12, 8))
sns.set_theme(style="white")
sns.boxplot(x='Condition', y='Value', hue='Group', data=df_all_conditions_std, palette=['yellow', 'cyan'], linewidth=2)
sns.stripplot(x='Condition', y='Value', hue='Group', data=df_all_conditions_std, palette=['red', 'red'], dodge=True, alpha=0.5, jitter=True)
plt.title('Standard deviation of basal body distance', fontsize=16)
plt.xlabel('Condition', fontsize=14)
plt.ylabel('\u03BCm', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
handles, labels = plt.gca().get_legend_handles_labels()
plt.legend(handles[0:2], labels[0:2], fontsize=12)
plt.savefig('comparison_std_bb_distance_all_conditions.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# Out:
# C:\Users\laan\AppData\Local\Temp\ipykernel_29492\2570211359.py:19: UserWarning: The palette list has more values (6) than needed (2), which may not be intended.
#   sns.boxplot(x='Condition', y='Value', hue='Group', data=df_all_conditions_mean, palette=custom_palette, linewidth=2, ax=ax, whiskerprops=dict(color='white'), capprops=dict(color='white'), medianprops=dict(color='white'))
# C:\Users\laan\AppData\Local\Temp\ipykernel_29492\2570211359.py:20: UserWarning: The palette list has more values (6) than needed (2), which may not be intended.
#   sns.stripplot(x='Condition', y='Value', hue='Group', data=df_all_conditions_mean, palette=['red', 'red', 'red', 'red', 'red', 'red'], dodge=True, jitter=True, size=4)

# %%
# Out:
# C:\Users\laan\AppData\Local\Temp\ipykernel_29492\708967724.py:36: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Condition', y='Value', data=df_all_conditions_mean, palette=custom_palette, linewidth=2, ax=ax, whiskerprops=dict(color='white'), capprops=dict(color='white'), medianprops=dict(color='white'), width=0.8, dodge=False)
# C:\Users\laan\AppData\Local\Temp\ipykernel_29492\708967724.py:37: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(x='Condition', y='Value', data=df_all_conditions_mean, palette=['red', 'red', 'red','red', 'red', 'red'], dodge=False, jitter=True, size=6)
